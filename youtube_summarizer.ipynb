# %%
print('hello')
# Out:
# hello

# %%
# !pip install --upgrade pip
# !pip install --upgrade notebook

# %%
# !pip install youtube_transcript_api==0.6.3

# %%
from youtube_transcript_api import YouTubeTranscriptApi
url = 'https://www.youtube.com/watch?v=nHTyRkzVZCU'
video_id = url.split('v=')[1]
transcript = YouTubeTranscriptApi().fetch(video_id)
print(transcript)
# Out:
# FetchedTranscript(snippets=[FetchedTranscriptSnippet(text='This is my YouTube channel. I posted my', start=0.24, duration=5.599), FetchedTranscriptSnippet(text='first video here on 25th August 2023', start=2.56, duration=5.6), FetchedTranscriptSnippet(text='thinking that no one would watch and I', start=5.839, duration=4.561), FetchedTranscriptSnippet(text='was right. For the first 6 months,', start=8.16, duration=4.88), FetchedTranscriptSnippet(text='almost no one cared. I was getting a few', start=10.4, duration=5.199), FetchedTranscriptSnippet(text='thousand views. It took me 6 months just', start=13.04, duration=5.84), FetchedTranscriptSnippet(text='to reach 10,000 subscribers. But then', start=15.599, duration=5.76), FetchedTranscriptSnippet(text='something changed. In the next 1 and 1/2', start=18.88, duration=4.639), FetchedTranscriptSnippet(text='years, this channel grew to 2 lakh', start=21.359, duration=3.84), FetchedTranscriptSnippet(text='subscribers. I started getting', start=23.519, duration=3.6), FetchedTranscriptSnippet(text='sponsorships from some of the biggest', start=25.199, duration=3.521), FetchedTranscriptSnippet(text='brands and I started getting more', start=27.119, duration=3.521), FetchedTranscriptSnippet(text='clients. And if you have seen my seven', start=28.72, duration=3.76), FetchedTranscriptSnippet(text='income source video, you would know that', start=30.64, duration=5.599), FetchedTranscriptSnippet(text='I made over 1.4 Kores in 2026. What most', start=32.48, duration=6.0), FetchedTranscriptSnippet(text='people miss is this. Six of my seven', start=36.239, duration=4.801), FetchedTranscriptSnippet(text='income sources exist because I started', start=38.48, duration=4.48), FetchedTranscriptSnippet(text='content creation. Not because I was', start=41.04, duration=4.24), FetchedTranscriptSnippet(text='famous, not because I was viral like Mr.', start=42.96, duration=5.279), FetchedTranscriptSnippet(text='Beast, but because content itself is a', start=45.28, duration=5.2), FetchedTranscriptSnippet(text='high lever skill. Even if you never', start=48.239, duration=4.181), FetchedTranscriptSnippet(text='become internet famous, content can', start=50.48, duration=3.68), FetchedTranscriptSnippet(text='[music] still change your life. It', start=52.42, duration=3.979), FetchedTranscriptSnippet(text='changes how you speak, how confident you', start=54.16, duration=4.8), FetchedTranscriptSnippet(text='are, how people perceive you, and yes,', start=56.399, duration=4.241), FetchedTranscriptSnippet(text='how much money you can make. Content', start=58.96, duration=3.759), FetchedTranscriptSnippet(text='creation is what you call an asymmetric', start=60.64, duration=4.4), FetchedTranscriptSnippet(text='return skill. That means the downside is', start=62.719, duration=4.801), FetchedTranscriptSnippet(text='very small, but the upside can be', start=65.04, duration=4.32), FetchedTranscriptSnippet(text="life-changing. You never know who's", start=67.52, duration=3.52), FetchedTranscriptSnippet(text='watching your content on the other side.', start=69.36, duration=3.92), FetchedTranscriptSnippet(text='I regularly get emails from people I', start=71.04, duration=4.64), FetchedTranscriptSnippet(text='never expected would even see my videos.', start=73.28, duration=4.479), FetchedTranscriptSnippet(text='Just because content travels further', start=75.68, duration=4.32), FetchedTranscriptSnippet(text="than you ever can. And as I've talked", start=77.759, duration=4.561), FetchedTranscriptSnippet(text='before, income in any industry follows a', start=80.0, duration=4.4), FetchedTranscriptSnippet(text='power law, which means a very small', start=82.32, duration=4.08), FetchedTranscriptSnippet(text='percentage of people make the majority', start=84.4, duration=3.84), FetchedTranscriptSnippet(text='of the money. But content creation is', start=86.4, duration=4.32), FetchedTranscriptSnippet(text='one of the easiest way to ...

# %%
text=' '.join([t.text for t in transcript])
print(text)
# Out:
# This is my YouTube channel. I posted my first video here on 25th August 2023 thinking that no one would watch and I was right. For the first 6 months, almost no one cared. I was getting a few thousand views. It took me 6 months just to reach 10,000 subscribers. But then something changed. In the next 1 and 1/2 years, this channel grew to 2 lakh subscribers. I started getting sponsorships from some of the biggest brands and I started getting more clients. And if you have seen my seven income source video, you would know that I made over 1.4 Kores in 2026. What most people miss is this. Six of my seven income sources exist because I started content creation. Not because I was famous, not because I was viral like Mr. Beast, but because content itself is a high lever skill. Even if you never become internet famous, content can [music] still change your life. It changes how you speak, how confident you are, how people perceive you, and yes, how much money you can make. Content creation is what you call an asymmetric return skill. That means the downside is very small, but the upside can be life-changing. You never know who's watching your content on the other side. I regularly get emails from people I never expected would even see my videos. Just because content travels further than you ever can. And as I've talked before, income in any industry follows a power law, which means a very small percentage of people make the majority of the money. But content creation is one of the easiest way to move yourself up to that top 10%. [music] So in this video, I'm going to break down why you should start making content in 2026, [music] even if no one watches. How to create content when you feel like you have nothing to say. How to build a personal brand better than 99% of people. How to actually start making money from your personal brand, which platform to use, how often you should post, and the only mindset you need to build a long-term career through content. If you are even slightly thinking about starting, this video could save you years. Let's first start with why almost no one thinks content is for them. Most people don't avoid making content because they're lazy. Is truly because they're afraid. Because we are social creatures, we really care about what other people think about us. The first thought is not what if this helps someone. It's what will people think if I talk to a camera? They'll think I'm stupid. They'll think I'm trying too hard. I felt the same. I'm not naturally extroverted. I was awkward on camera and I used to talk like a robot. No confidence and no experience. But here's the truth. You'll never feel ready. Readiness is not a feeling. It's something you build by publishing. Your first few pieces of content are not for the audience. They are proof for you. The people you watch today did not start confident or polished. They became that by publishing while they were bad at it. Most people still treat internet like entertainment only. Memes, reals, trends. But the people who want to do meaningful work see it differently. They see it as leverage. Today you don't need TV, radio or ads to reach people. You just need to put your ideas online and let them travel. That's why content is one of those few tools that gives ordinary people like you and me unfair reach. But is 2026 too late to start already? Let me give you a reality check. 2026 is actually the best time to get started because the creator economy is growing rapidly, expected to hit 1 trillion by early 2030. Just a few years ago, brands controlled attention. They had the budgets, the platforms, and the reach. That power is now shifting to individuals. It's also easier than ever to start. You don't need expensive cameras. You don't need perfect editing. You don't need a team. What you need is clear thinking, real experience, and the ability to publish consistently. Today, one person with a phone, ideas, and consistency can out compete entire teams. Not by spending m ...

# %%
# !pip install groq
from groq import Groq

client = Groq(api_key="your_api_key_here")

response1 = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[{
        "role": "user",
        "content": f"Add proper punctuation and capitalization to this transcript. Return only the corrected text:\n\n{text}"
    }]
)
punctuated_text = response1.choices[0].message.content

response2 = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[{
        "role": "user",
        "content": f"Summarize the text:\n\n{text}"
    }]
)

summary = response2.choices[0].message.content
print(summary)
# Out:
# Requirement already satisfied: groq in C:\Users\Coll\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.2.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in C:\Users\Coll\AppData\Local\Programs\Python\Python313\Lib\site-packages (from groq) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\Coll\AppData\Local\Programs\Python\Python313\Lib\site-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\Coll\AppData\Local\Programs\Python\Python313\Lib\site-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in C:\Users\Coll\AppData\Local\Programs\Python\Python313\Lib\site-packages (from groq) (2.13.4)
# Requirement already satisfied: sniffio in C:\Users\Coll\AppData\Local\Programs\Python\Python313\Lib\site-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in C:\Users\Coll\AppData\Local\Programs\Python\Python313\Lib\site-packages (from groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in C:\Users\Coll\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anyio<5,>=3.5.0->groq) (3.13)
# Requirement already satisfied: certifi in C:\Users\Coll\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1,>=0.23.0->groq) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\Coll\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\Coll\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\Coll\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\Coll\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3,>=1.9.0->groq) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\Coll\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)
# The video is about the importance of creating content on social media, specifically on YouTube, to build a personal brand and generate income. The creator of the channel shares their own experience of starting a YouTube channel in 2023, initially struggling for views and subscribers, but eventually growing the channel to 2 lakh subscribers and generating over 1.4 lakhs Kores in income.
#
# The creator emphasizes that content creation is a high-lever skill that can change one's life, regardless of fame or viral status. They mention the asymmetric return skill, where the downside is small, but the upside can be life-changing. They also explain that income in any industry follows a power law, where a small percentage of people make the majority of the money, but content creation is one of the easiest ways to move up to that top 10%.
#
# The creator breaks down the process of creating content, building a personal brand, and monetizing it. They discuss the importance of being consistent, using a variety of content formats, and being authentic.
#
# Here are the key takeaways from the video:
#
# 1. **Content creation is a high-lever skill**: It can change your life, regardless of fame or viral status.
# 2. **Asymmetric return skill**: The downside is small, but the upside can be life-changing.
# 3. **Income in any industry follows a power law**: A small percentage of people make the majority of the money, but content creation is one of the easiest ways to move up to that top 10%.
# 4. **Create content for three versions of yourself**: Past, present, and future self.
# 5. **Identify your unfair advantage**: What can you talk about that others can't?
# 6. **Build a personal brand**: Create a strong personal brand on three pillars: growth, authenticity, and authority.
# 7. **Monetize your personal brand**: Use platforms like Super Profile to turn attention into income without relying on multiple tools or complicated setups.
# 8. **Start small and test demand**: Validate the problem, validate that people will pay, and only then build the product or service.
# 9. **Consistency is key**: Publish regularly and pay attention to patterns.
# 10. **Take action**: Don't wait for the perfect conditions to start; start now and take action.
#
# The creator also provides a three-month plan to get started with building a personal brand and monetizing it:
#
# Month 1: **Pick and start**
#
# * Pick one platform
# * Create a simple content plan
# * Publish fast and with intention
# * Set a target for 20 pieces of content
#
# Month 2: **Learn from reality**
#
# * Keep posting and paying attention
# * Filter out the ideas that worked
# * Collect data
#
# Month 3: **Double down and test monetization**
#
# * Look back and pick five pieces of content that performed better than the rest
# * Refine the angles and go deeper
# * Create a simple digital product or service around the problem it solves and test if people are willing to pay for it
